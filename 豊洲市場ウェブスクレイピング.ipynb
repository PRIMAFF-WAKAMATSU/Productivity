# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIMAFF-WAKAMATSU/Productivity/blob/main/%E8%B1%8A%E6%B4%B2%E5%B8%82%E5%A0%B4%E3%82%A6%E3%82%A7%E3%83%96%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ウェブスクレイピング
# 豊洲市場の２０１９年～２０２４年までの日別販売データ（CSV)をダウンロードする

# %%
# １）東京中央卸売市場日別販売実績のページ https://www.shijou-nippo.metro.tokyo.lg.jp/SN/SN_Sui_Nengetu.html
# に行き、2019年～2024年のページで、
# https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/SN_Sui_Hi.html
# ２）全ての営業日において、
# https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190105/SN_Sui_Shijou.html
# ３）豊洲市場を選択し、
# https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190105/Sui/SN_Sui_Toyosu_index.html
# ４）その中のCSVファイルをダウンロードする。
# https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190105/Sui/Sui_K1.csv
# ５）できない場合（エラー）は次の営業日に移る。

import os
import time
import requests
import shutil
from google.colab import files


# 保存ディレクトリを作成
save_dir = "tokyo_market_data"
os.makedirs(save_dir, exist_ok=True)

# 取得対象の年と月
years = [2019, 2020, 2021, 2022, 2023, 2024]

# 各年・各月の営業日ごとにデータを取得
for year in years:
    for month in range(1, 13):  # 1月から12月
        month_str = f"{year}{month:02d}"
        base_url = f"https://www.shijou-nippo.metro.tokyo.lg.jp/SN/{month_str}"

        # 1日から31日まで順番に試す（該当日が存在しなければスキップ）
        for day in range(1, 32):  # 1日～31日
            date_str = f"{year}{month:02d}{day:02d}"
            csv_url = f"{base_url}/{date_str}/Sui/Sui_K1.csv"
            file_path = os.path.join(save_dir, f"Sui_K1_{date_str}.csv")

            try:
                response = requests.get(csv_url, headers={"User-Agent": "Mozilla/5.0"}, timeout=30)

                # ステータスコードが200ならダウンロード
                if response.status_code == 200:
                    with open(file_path, "wb") as file:
                        file.write(response.content)
                    print(f"Downloaded: {csv_url}")

                else:
                    print(f"Skipping (Not Found): {csv_url}")

            except Exception as e:
                print(f"Error fetching {csv_url}: {e}")

            # 6秒間のウェイト（サーバーへの負荷軽減）
            time.sleep(6)

print("Data download completed.")

# フォルダをZIP圧縮（例: "tokyo_market_data" を圧縮）
shutil.make_archive("market_data", 'zip', "tokyo_market_data")

# 圧縮したファイルをダウンロード
files.download("market_data.zip")
# Out:
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190101/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190102/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190103/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190104/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190105/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190106/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190107/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190108/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190109/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190110/Sui/Sui_K1.csv
# ...

# %%
# prompt: log_of_webscraping.txtを読み込み、「Error fetching」から始まる行だけを残す

def filter_error_lines(file_path):
  """
  ログファイルを読み込み、「Error fetching」から始まる行だけを残す。

  Args:
      file_path: ログファイルのパス。

  Returns:
      「Error fetching」から始まる行のみを含むリスト。
  """

  with open(file_path, 'r') as f:
    lines = f.readlines()

  error_lines = [line for line in lines if line.startswith('Error fetching')]
  return error_lines


if __name__ == '__main__':
  file_path = 'log_of_webscraping.txt'  # ログファイルのパス
  error_lines = filter_error_lines(file_path)
  for line in error_lines:
      print(line, end="")
# Out:
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190111/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190111/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed6c10>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190121/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190121/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ec3090>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# ...

# %%
import os
import time
import requests
import re

# ファイルパス（エラーリンクが記録されたファイル）
error_log_path = "error_fetching.txt"

# ダウンロード先フォルダ
save_dir = "tokyo_market_data"
os.makedirs(save_dir, exist_ok=True)

# エラーURLを抽出
failed_urls = []
with open(error_log_path, "r") as file:
    for line in file:
        match = re.search(r"Error fetching (https://www\.shijou-nippo\.metro\.tokyo\.lg\.jp/SN/(\d{6})/(\d{8})/Sui/Sui_K1\.csv)", line)
        if match:
            url = match.group(1)  # フルURL
            date_str = match.group(3)  # YYYYMMDD
            failed_urls.append((url, date_str))

# ダウンロード処理
for url, date_str in failed_urls:
    file_name = f"Sui_K1_{date_str}.csv"
    file_path = os.path.join(save_dir, file_name)

    try:
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=30)

        if response.status_code == 200:
            with open(file_path, "wb") as file:
                file.write(response.content)
            print(f"✅ Downloaded: {file_name}")
        else:
            print(f"🚫 Not Found (Skipping): {url}")

    except requests.exceptions.RequestException as e:
        print(f"❌ Failed again: {url} | Error: {e}")

    # 6秒間のウェイト（サーバー負荷軽減）
    time.sleep(6)

print("🎉 Retry process completed.")
# Out:
# ✅ Downloaded: Sui_K1_20190111.csv
# ✅ Downloaded: Sui_K1_20190121.csv
# ✅ Downloaded: Sui_K1_20190128.csv
# ✅ Downloaded: Sui_K1_20190131.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190206/Sui/Sui_K1.csv
# ✅ Downloaded: Sui_K1_20190208.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190211/Sui/Sui_K1.csv
# ✅ Downloaded: Sui_K1_20190215.csv
# ✅ Downloaded: Sui_K1_20190216.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190224/Sui/Sui_K1.csv
# ✅ Downloaded: Sui_K1_20190226.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190227/Sui/Sui_K1.csv
# ✅ Downloaded: Sui_K1_20190302.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190303/Sui/Sui_K1.csv
# 🚫 Not Found (Skipping): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190306/Sui/Sui_K1.csv
# ...

# %%
import shutil
from google.colab import files
# フォルダをZIP圧縮（例: "tokyo_market_data" を圧縮）
shutil.make_archive("market_data", 'zip', "tokyo_market_data")

# 圧縮したファイルをダウンロード
files.download("market_data.zip")

# %% [markdown]
# Log of web scraping
#
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190101/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190102/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190103/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190104/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190105/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190106/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190107/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190108/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190109/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190110/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190111/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190111/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed6c10>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190112/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190113/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190114/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190115/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190116/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190117/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190118/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190119/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190120/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190121/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190121/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ec3090>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190122/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190123/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190124/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190125/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190126/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190127/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190128/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190128/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed7950>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190129/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190130/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201901/20190131/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201901/20190131/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec8ba5b3690>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190201/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190202/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190203/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190204/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190205/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190206/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190206/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d2ac50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190207/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190208/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190208/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec8ba5a1a50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190209/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190210/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190211/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190211/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898cf6110>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190212/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190213/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190214/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190215/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190215/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed5050>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190216/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190216/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ecf9d0>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190217/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190218/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190219/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190220/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190221/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190222/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190223/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190224/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190224/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec8ba5b2c50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190225/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190226/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190226/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d29b50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190227/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201902/20190227/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ec0b90>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190228/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190229/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190230/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201902/20190231/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190301/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190302/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190302/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ec24d0>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190303/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190303/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d2a4d0>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190304/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190305/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190306/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190306/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed4b10>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190307/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190308/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190309/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190310/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190310/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d29050>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190311/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190312/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190313/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190314/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190315/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190316/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190317/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190318/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190318/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d2b890>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190319/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190320/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190321/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190322/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190323/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190324/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190325/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190326/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190327/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190328/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190328/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ecda50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190329/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190330/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201903/20190331/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201903/20190331/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ff8d50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190401/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190401/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898d0f350>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190402/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190403/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190404/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190405/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190406/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190407/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190408/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190409/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190410/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190411/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190412/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190413/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190414/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190414/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898cf5010>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190415/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190416/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190417/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190418/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190418/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec8ba5a1f50>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190419/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190419/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed4f90>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190420/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190421/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190422/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190423/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190424/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190424/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ed6290>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190425/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190426/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190427/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190428/Sui/Sui_K1.csv: HTTPSConnectionPool(host='www.shijou-nippo.metro.tokyo.lg.jp', port=443): Max retries exceeded with url: /SN/201904/20190428/Sui/Sui_K1.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec898ff0290>, 'Connection to www.shijou-nippo.metro.tokyo.lg.jp timed out. (connect timeout=30)'))
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190429/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190430/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201904/20190431/Sui/Sui_K1.csv
# Skipping (Not Found): https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201905/20190501/Sui/Sui_K1.csv
# Downloaded: https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201905/20190502/Sui/Sui_K1.csv
# Error fetching https://www.shijou-nippo.metro.tokyo.lg.jp/SN/201905/20